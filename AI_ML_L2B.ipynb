# %%
#1 RANDOM FOREST CLASSIFICATION OF IRIS DATASET
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import learning_curve
from sklearn.model_selection import train_test_split
df=pd.read_csv(r'C:\Users\Niketa Mittal\Downloads\Iris.csv')
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Species']=le.fit_transform(df['Species'])
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        0
# 1              4.9           3.0            1.4           0.2        0
# 2              4.7           3.2            1.3           0.2        0
# 3              4.6           3.1            1.5           0.2        0
# 4              5.0           3.6            1.4           0.2        0
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        2
# 146            6.3           2.5            5.0           1.9        2
# 147            6.5           3.0            5.2           2.0        2
# 148            6.2           3.4            5.4           2.3        2
# 149            5.9           3.0            5.1           1.8        2
#
# [150 rows x 5 columns]

# %%
x=df.iloc[:,0:4]
y=df.iloc[:,4]
x.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
#Random Forest Classification
from sklearn.ensemble import RandomForestClassifier
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=0)
rfc=RandomForestClassifier()
rfc=rfc.fit(x_train,y_train)
y_pred=rfc.predict(x_test)
y_pred
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 1, 0, 2, 2, 1, 0, 2, 1, 1, 2, 0, 2, 0,
#        0, 1, 2, 2, 1, 2, 1, 2, 1])

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
# Out:
# [[16  0  0]
#  [ 0 20  1]
#  [ 0  1 15]]
# 0.9622641509433962

# %%
train_sizes, train_scores, test_scores= learning_curve(rfc, x,y, train_sizes=[0.2,0.4,0.5,0.75,0.8,0.9], cv=10)
train_mean=np.mean(train_scores, axis=1)
test_mean=np.mean(test_scores, axis=1)
plt.plot(train_sizes, train_mean,'o-', color="r", label="Training score")
plt.plot(train_sizes, test_mean, 'o-', color="g", label="Test score")
plt.legend(loc="best")

# %%
#2 APRIORI ALGORITHMN ON RETAIL TRANSACTION DATASET
from mlxtend.frequent_patterns import apriori, association_rules
df=pd.read_excel(r'C:\Users\Niketa Mittal\Downloads\Online_Retail.xlsx')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
df.shape
# Out:
# (541909, 8)

# %%
df['Description']=df['Description'].str.strip()

# %%
df.dropna(axis=0,subset=['InvoiceNo'],inplace=True)

# %%
df=df.drop_duplicates()
df.shape
# Out:
# (536641, 8)

# %%
df=df[~df['InvoiceNo'].str.contains('C', na=False)]
df.shape
# Out:
# (527390, 8)

# %%
def hot_encode(x): 
    if(x<= 0): 
        return 0
    if(x>= 1): 
        return 1

# %%
df=(df.groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')) 
df.head()
# Out:
# Description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# InvoiceNo
# 536365                         0.0                      0.0
# 536366                         0.0                      0.0
# 536367                         0.0                      0.0
# 536368                         0.0                      0.0
# 536369                         0.0                      0.0
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                          0.0                         0.0
# 536366                          0.0                         0.0
# 536367                          0.0                         0.0
# 536368                          0.0                         0.0
# 536369                          0.0                         0.0
#
# Description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536365                             0.0                        0.0
# ...

# %%
df=df.applymap(hot_encode)
df.shape
# Out:
# (20609, 4194)

# %%
items=apriori(df,min_support=0.03, use_colnames=True)
np.shape(items)
# Out:
# (126, 2)

# %%
rules=association_rules(items, metric='lift', min_threshold=0.5)
rules.head()
# Out:
#                          antecedents                        consequents  \
# 0         (ALARM CLOCK BAKELIKE RED)       (ALARM CLOCK BAKELIKE GREEN)
# 1       (ALARM CLOCK BAKELIKE GREEN)         (ALARM CLOCK BAKELIKE RED)
# 2  (GREEN REGENCY TEACUP AND SAUCER)   (PINK REGENCY TEACUP AND SAUCER)
# 3   (PINK REGENCY TEACUP AND SAUCER)  (GREEN REGENCY TEACUP AND SAUCER)
# 4  (ROSES REGENCY TEACUP AND SAUCER)  (GREEN REGENCY TEACUP AND SAUCER)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.050997            0.047552  0.031054    0.608944  12.805841
# 1            0.047552            0.050997  0.031054    0.653061  12.805841
# 2            0.049250            0.037168  0.030715    0.623645  16.778990
# 3            0.037168            0.049250  0.030715    0.826371  16.778990
# 4            0.051725            0.049250  0.037265    0.720450  14.628335
#
#    leverage  conviction
# 0  0.028629    2.435579
# 1  0.028629    2.735361
# ...

# %%
# ECLAT ALGORITHMN
from itertools import chain, combinations
kot=0
freqItems=dict()
support=dict()
def eclat(prefix, items, dict_id):
    while items:
        i,itids=items.pop()
        isupp=len(itids)
        if isupp>=minsupp:
            freqItems[frozenset(prefix+[i])] = isupp
            suffix=[]
            for j, ojtids in items:
                jtids=itids&ojtids
                if len(jtids)>=minsupp:
                    suffix.append((j,jtids))
            dict_id+=1
            eclat(prefix+[i],sorted(suffix, key=lambda item: len(item[1])),dict_id)

# %%
def rules(freqItems,confidence):
    Rules=[]
    cnt=0
    for items,support in freqItems.items():
        if len(items)>1:
            lst=list(items)
            antecedent=lst[:len(lst)-1]
            consequent=lst[-1:]
            conf=float(freqItems[frozenset(items)]/freqItems[frozenset(antecedent)])
            if conf>=confidence:
                cnt+=1
                Rules.append((antecedent,consequent,support,conf))
    print('found %d rules'%(cnt))
    return Rules

# %%
def print_frequent_itemsets(output_freqitems, freqItems):
    file=open(output_freqitems,'w+')
    for item,support in freqItems.items():
        file.write("{} : {}\n".format(list(item),round(support,4)))
    file.close()

# %%
def print_rules(output_file,Rules):
    file=open(output_file,'w+')
    for ant,con,sup,conf in sorted(Rules):
        file.write("Rule: {} ==> {} : {} : {}\n".format((ant),(con),round(sup,4),round(conf,4)))
    file.close()

# %%
def read_data(filename, delimiter=','):
    data={}
    trans=0
    f=open(filename,'r')
    for row in f:
        trans+=1
        for item in row.split(delimiter):
            if item not in data:
                data[item]=set()
            data[item].add(trans)
    f.close()
    return data

# %%
if __name__=="__main__":
    minsupp=2
    confidence=30
    output_freqitems="output_freqitems.csv"
    output_file="output_rules.csv"
    dict_id=0
    data1=read_data(r"C:\Users\Niketa Mittal\Downloads\Market_Basket_Optimisation.csv",',')
    eclat([], sorted(data1.items(), key=lambda item: len(item[1]), reverse=True), dict_id)
    Rules=rules(freqItems,confidence)
    print('found %d frequent items'%len(freqItems))
    print('Writing rules.....')
    print_frequent_itemsets(output_freqitems,freqItems)
    print_rules(output_file,Rules)
    print('Files written successfully')
# Out:
# found 0 rules
# found 388799 frequent items
# Writing rules.....
# Files written successfully

# %%
#FP GROWTH ALGORITHMN
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth
te=TransactionEncoder()
df=pd.read_csv(r'C:\Users\Niketa Mittal\Downloads\Market_Basket_Optimisation.csv', header=None)
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
df_new=df.apply(lambda x: list(x.dropna().values), axis=1).tolist()
te_new=te.fit(df_new).transform(df_new)
df2=pd.DataFrame(te_new, columns=te.columns_)
df2.head()
# Out:
#     asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0       False     True               True      False     True        False
# 1       False    False              False      False    False        False
# 2       False    False              False      False    False        False
# 3       False    False              False      False     True        False
# 4       False    False              False      False    False        False
#
#    bacon  barbecue sauce  black tea  blueberries  ...  turkey  vegetables mix  \
# 0  False           False      False        False  ...   False            True
# 1  False           False      False        False  ...   False           False
# 2  False           False      False        False  ...   False           False
# 3  False           False      False        False  ...    True           False
# 4  False           False      False        False  ...   False           False
#
# ...

# %%
fpgrowth(df2, min_support=0.02,use_colnames=True)
# Out:
#       support                      itemsets
# 0    0.238368               (mineral water)
# 1    0.132116                   (green tea)
# 2    0.076523              (low fat yogurt)
# 3    0.071457                      (shrimp)
# 4    0.065858                   (olive oil)
# ..        ...                           ...
# 98   0.040928  (ground beef, mineral water)
# 99   0.039195      (ground beef, spaghetti)
# 100  0.021997           (ground beef, milk)
# 101  0.023064      (chocolate, ground beef)
# 102  0.027463         (cake, mineral water)
#
# [103 rows x 2 columns]

# %%
#4 RECOMMENDATION SYSTEM USING MOVIE RATINGS DATASET
import math
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.model_selection import KFold
from sklearn.neighbors import NearestNeighbors
import warnings
from fuzzywuzzy import fuzz
warnings.simplefilter("error")
df_ratings=pd.read_csv(r'C:\Users\Niketa Mittal\Downloads\ml-latest-small\ratings.csv')
df_movies=pd.read_csv(r'C:\Users\Niketa Mittal\Downloads\ml-latest-small\movies.csv')
df_tags=pd.read_csv(r'C:\Users\Niketa Mittal\Downloads\ml-latest-small\tags.csv')
# Out:
# C:\Users\Niketa Mittal\Anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
df_movie_count=pd.DataFrame(df_ratings.groupby('movieId').size(), columns=['count'])
popular_movies=list(df_movie_count[df_movie_count['count']>10].index)
movie_filter=df_ratings.movieId.isin(popular_movies).values
movie_filter
# Out:
# array([ True,  True,  True, ...,  True,  True, False])

# %%
df_user_count=pd.DataFrame(df_ratings.groupby('userId').size(), columns=['count'])
active_users=list(df_user_count[df_user_count['count']>10].index)
user_filter=df_ratings.userId.isin(active_users).values
user_filter
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
df_rating_filtered=df_ratings[movie_filter&user_filter]
df_rating_filtered
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100818     610   159093     3.0  1493847704
# 100829     610   164179     5.0  1493845631
# 100830     610   166528     4.0  1493879365
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
#
# [79636 rows x 4 columns]

# %%
movie_user_matrix=df_rating_filtered.pivot(index='movieId',columns='userId',values='rating').fillna(0)
hashmap={movie:i for i,movie in
        enumerate(list(df_movies.set_index('movieId').loc[movie_user_matrix.index].title))}
movie_matrix_sparse=csr_matrix(movie_user_matrix.values)
movie_matrix_sparse
# Out:
# <2121x610 sparse matrix of type '<class 'numpy.float64'>'
# 	with 79636 stored elements in Compressed Sparse Row format>

# %%
def fuzzy_matching(hashmap, fav_movie):
    match_tuple=[]
    for title,indx in hashmap.items():
        ratio=fuzz.ratio(title.lower(),fav_movie.lower())
        if ratio>=60:
            match_tuple.append((title,indx,ratio))
    match_tuple=sorted(match_tuple,key=lambda x: x[2])[::-1]
    if not match_tuple:
        print("no match found")
    else:
        print('possible matches found: {0}\n'.format([x[0] for x in match_tuple]))
    return match_tuple[0][1]

# %%
def inference(data,hashmap,fav_movie,n_recomm):
    model=NearestNeighbors(metric='cosine',algorithm='brute', n_neighbors=20, n_jobs=-1)
    model.fit(data)
    print('input movie is: ',fav_movie)
    idx=fuzzy_matching(hashmap,fav_movie)
    print('starting inference by recommendation system:')
    print('-------\n')
    #t0=time.time()
    distances,indices=model.kneighbors(data[idx], n_neighbors=n_recomm+1)
    raw_recomm=sorted(list(zip(indices.squeeze().tolist(),distances.squeeze().tolist())),key=lambda x: x[1])[:0:-1]
    return raw_recomm

# %%
fav_movie='Iron Man'
top_n=10
recomm=inference(movie_matrix_sparse, hashmap,fav_movie,top_n)
rev_hashmap={v:k for k,v in hashmap.items()}
print('recommendations for {}: '.format(fav_movie))
for i, (idx,dist) in enumerate(recomm):
    print('{0}: {1}, with distance of {2}'.format(i+1,rev_hashmap[idx], dist))
# Out:
# input movie is:  Iron Man
# possible matches found: ['Iron Man (2008)', 'Iron Man 3 (2013)', 'Iron Man 2 (2010)']
#
# starting inference by recommendation system:
# -------
#
# recommendations for Iron Man:
# 1: Star Trek (2009), with distance of 0.4175134166051351
# 2: Guardians of the Galaxy (2014), with distance of 0.4110291189201821
# 3: Thor (2011), with distance of 0.4105084379024724
# 4: Up (2009), with distance of 0.40326434789507326
# 5: Batman Begins (2005), with distance of 0.4029287417301053
# 6: Avatar (2009), with distance of 0.3757322316601438
# 7: Iron Man 2 (2010), with distance of 0.35801447096159067
# 8: Avengers, The (2012), with distance of 0.3413244923996469
# 9: WALL·E (2008), with distance of 0.3322251199632066
# 10: Dark Knight, The (2008), with distance of 0.32946219051576764

# %%
#5 TIME SERIES ANALYSIS FOR DOW-JONES AND NASDAQ DATASET
import pandas as pd
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.arima_model import ARIMA
df=pd.read_csv(r'C:\Users\Niketa Mittal\Downloads\chasewillden-stock-market-from-a-high-level\DowJones.csv')
df.head()
# Out:
#          Date   Value
# 0  1977-09-02  872.31
# 1  1977-09-09  857.04
# 2  1977-09-16  856.81
# 3  1977-09-23  839.14
# 4  1977-09-30  847.11

# %%
plt.plot(df['Date'],df['Value'])

# %%
model=ARMA(df.Value,order=(6,0))
model=model.fit(disp=0)
y=model.predict(df.shape[0],df.shape[0])
y
# Out:
# 2082    21875.834725
# dtype: float64

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ...
# Dep. Variable:                  Value   No. Observations:                 2082
# Model:                     ARMA(6, 0)   Log Likelihood              -13845.027
# Method:                       css-mle   S.D. of innovations            186.606
# Date:                Sat, 09 May 2020   AIC                          27706.053
# Time:                        20:42:58   BIC                          27751.182
# Sample:                             0   HQIC                         27722.590
#
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        7284.2487   1.11e+04      0.654      0.513   -1.46e+04    2.91e+04
# ar.L1.Value     0.9260      0.004    231.027      0.000       0.918       0.934
# ...

# %%
model=ARIMA(df.Value,order=(6,1,0))
model=model.fit(disp=0)
y=model.predict(df.shape[0],df.shape[0])
y
# Out:
# 2082    30.249293
# dtype: float64

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.Value   No. Observations:                 2081
# Model:                 ARIMA(6, 1, 0)   Log Likelihood              -13830.048
# Method:                       css-mle   S.D. of innovations            186.219
# Date:                Sat, 09 May 2020   AIC                          27676.097
# Time:                        20:43:12   BIC                          27721.222
# Sample:                             1   HQIC                         27692.633
#
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            10.0967      3.752      2.691      0.007       2.743      17.451
# ar.L1.D.Value    -0.0771      0.022     -3.519      0.000      -0.120      -0.034
# ...

# %%
#6 K-MEANS CLUSTERING ON ONLINE RETAIL CUSTOMER DATA
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
# %matplotlib inline
df=pd.read_excel(r'C:\Users\Niketa Mittal\Downloads\Online_Retail.xlsx', encoding='ISO-8859-1')
df=df.drop(['StockCode','Country','Description'], axis=1)
df.head()
# Out:
#   InvoiceNo  Quantity         InvoiceDate  UnitPrice  CustomerID
# 0    536365         6 2010-12-01 08:26:00       2.55     17850.0
# 1    536365         6 2010-12-01 08:26:00       3.39     17850.0
# 2    536365         8 2010-12-01 08:26:00       2.75     17850.0
# 3    536365         6 2010-12-01 08:26:00       3.39     17850.0
# 4    536365         6 2010-12-01 08:26:00       3.39     17850.0

# %%
df.isna().sum()
df.shape
# Out:
# (541909, 5)

# %%
df.dropna(axis=0,subset=['CustomerID'],inplace=True)
df.shape
# Out:
# (406829, 5)

# %%
df['Amount']=df.Quantity*df.UnitPrice
df.head()
# Out:
#   InvoiceNo  Quantity         InvoiceDate  UnitPrice  CustomerID  Amount
# 0    536365         6 2010-12-01 08:26:00       2.55     17850.0   15.30
# 1    536365         6 2010-12-01 08:26:00       3.39     17850.0   20.34
# 2    536365         8 2010-12-01 08:26:00       2.75     17850.0   22.00
# 3    536365         6 2010-12-01 08:26:00       3.39     17850.0   20.34
# 4    536365         6 2010-12-01 08:26:00       3.39     17850.0   20.34

# %%
df1=df.groupby('CustomerID').Amount.sum()
df1=df1.reset_index()
df1.shape
# Out:
# (4372, 2)

# %%
df1.head()
# Out:
#    CustomerID   Amount
# 0     12346.0     0.00
# 1     12347.0  4310.00
# 2     12348.0  1797.24
# 3     12349.0  1757.55
# 4     12350.0   334.40

# %%
df2=df.groupby('CustomerID').InvoiceNo.count()
df2=df2.reset_index()
df2.shape
# Out:
# (4372, 2)

# %%
df2.head()
# Out:
#    CustomerID  InvoiceNo
# 0     12346.0          2
# 1     12347.0        182
# 2     12348.0         31
# 3     12349.0         73
# 4     12350.0         17

# %%
df3=pd.merge(df1,df2, on='CustomerID',how='inner')
df3.head()
# Out:
#    CustomerID   Amount  InvoiceNo
# 0     12346.0     0.00          2
# 1     12347.0  4310.00        182
# 2     12348.0  1797.24         31
# 3     12349.0  1757.55         73
# 4     12350.0   334.40         17

# %%
scX=StandardScaler()
df3=scX.fit_transform(df3)
df3.shape
# Out:
# (4372, 3)

# %%
from scipy.spatial.distance import cdist
from sklearn.metrics import silhouette_score
distort=[]
r=range(2,10)
for i in r:
    Kcluster=KMeans(n_clusters=i).fit(df3)
    predicts=Kcluster.fit_predict(df3)
    sills=silhouette_score(df3,predicts,metric='euclidean')
    distort.append(sills)
plt.plot(r,distort,'bx-')
plt.xlabel('no. of clusters')
plt.ylabel('distortions')
plt.show()

# %%
kmeans=KMeans(n_clusters=5)
y_pred=kmeans.fit_predict(df3)
# Visualising the clusters
plt.scatter(df3[y_pred == 0, 0], df3[y_pred == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(df3[y_pred == 1, 0], df3[y_pred == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(df3[y_pred == 2, 0], df3[y_pred == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(df3[y_pred == 3, 0], df3[y_pred == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(df3[y_pred == 4, 0], df3[y_pred == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.legend()
plt.show()
